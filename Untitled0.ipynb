# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil
source_path = '/content/drive/MyDrive/open (1).zip'
destination_path = '/content/open (1).zip'
shutil.copyfile(source_path, destination_path)
# Out:
# '/content/open (1).zip'

# %%
import zipfile
import os

# 압축 파일 경로
zip_file_path = '/content/open (1).zip'

# 압축을 해제할 폴더 경로 (현재 디렉토리에 'extracted'라는 폴더를 만듭니다)
extract_path = '/content/extracted'

# 압축 해제할 폴더가 없다면 생성합니다.
os.makedirs(extract_path, exist_ok=True)

try:
    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)
    print(f"'{zip_file_path}' 파일의 압축이 '{extract_path}' 폴더에 성공적으로 해제되었습니다.")
except FileNotFoundError:
    print(f"오류: '{zip_file_path}' 파일을 찾을 수 없습니다. 파일 경로를 확인해주세요.")
except zipfile.BadZipFile:
    print(f"오류: '{zip_file_path}' 파일이 올바른 ZIP 파일 형식이 아닙니다.")
except Exception as e:
    print(f"압축 해제 중 오류가 발생했습니다: {e}")
# Out:
# '/content/open (1).zip' 파일의 압축이 '/content/extracted' 폴더에 성공적으로 해제되었습니다.

# %%
import os
import pandas as pd
from PIL import Image
from torchvision import transforms, models
from torch.utils.data import Dataset, DataLoader
import torch
import torch.nn as nn
import torch.optim as optim

# %%
# 1. 데이터 로딩
train_df = pd.read_csv('extracted/train.csv')
test_df = pd.read_csv('extracted/test.csv')
artists_info = pd.read_csv('extracted/artists_info.csv')  # 포함

# %%
# 2. 화가 이름 → 숫자 라벨
unique_artists = artists_info['name'].tolist()  # artists_info 기준
label_mapping = {name: i for i, name in enumerate(unique_artists)}

train_df['label'] = train_df['artist'].map(label_mapping)
test_df['label'] = -1  # 테스트 데이터는 예측 대상

# %%
# 3. 이미지 경로 설정
train_df['img_path'] = train_df['img_path']
test_df['img_path'] = test_df['img_path']

# %%
# 4. 이미지 전처리
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

# %%
# 5. Dataset 클래스 정의
class ArtDataset(Dataset):
    def __init__(self, dataframe, root_dir, transform=None, is_test=False):
        self.dataframe = dataframe
        self.root_dir = root_dir
        self.transform = transform
        self.is_test = is_test

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        img_name = self.dataframe.iloc[idx]['img_path']
        img_path = os.path.join(self.root_dir, img_name)
        image = Image.open(img_path).convert("RGB")
        if self.transform:
            image = self.transform(image)

        if self.is_test:
            return image
        else:
            label = self.dataframe.iloc[idx]['label']
            return image, label

# %%
# 6. 데이터로더
train_dataset = ArtDataset(train_df, 'extracted', transform=transform)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

test_dataset = ArtDataset(test_df, 'extracted', transform=transform, is_test=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
# 7. 모델 정의 (ResNet18)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = models.resnet18(pretrained=True)
model.fc = nn.Linear(model.fc.in_features, len(label_mapping))
model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 192MB/s]

# %%
# 8. 모델 학습
for epoch in range(3):  # 3 에폭 예시
    model.train()
    total_loss = 0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        # 라벨 값이 올바른 범위 내에 있는지 확인
        print(labels.min(), labels.max())

        labels = labels.long()  # 라벨 타입 변경

        # 라벨 값이 잘못된 경우 처리
        labels = torch.clamp(labels, min=0)  # 0보다 작은 값을 0으로 처리

        outputs = model(images)
        loss = criterion(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    print(f"Epoch [{epoch+1}/3], Loss: {total_loss:.4f}")
# Out:
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(4., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(5., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(3., device='cuda:0', dtype=torch.float64) tensor(48., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(42., device='cuda:0', dtype=torch.float64)
# tensor(6., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(3., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(49., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(1., device='cuda:0', dtype=torch.float64) tensor(44., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(8., device='cuda:0', dtype=torch.float64) tensor(49., device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(49., device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(48., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(48., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(48., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(2., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(45., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(49., device='cuda:0', dtype=torch.float64)
# tensor(4., device='cuda:0', dtype=torch.float64) tensor(45., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(4., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(2., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(48., device='cuda:0', dtype=torch.float64)
# tensor(4., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(8., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(4., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(1., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(49., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(44., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(1., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(1., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(49., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(4., device='cuda:0', dtype=torch.float64) tensor(49., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(40., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(48., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(3., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(4., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(48., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(3., device='cuda:0', dtype=torch.float64) tensor(42., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# Epoch [1/3], Loss: 472.3474
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(2., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(1., device='cuda:0', dtype=torch.float64) tensor(45., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(2., device='cuda:0', dtype=torch.float64) tensor(42., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(1., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(4., device='cuda:0', dtype=torch.float64) tensor(49., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(2., device='cuda:0', dtype=torch.float64) tensor(48., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(2., device='cuda:0', dtype=torch.float64) tensor(49., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(48., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(1., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(3., device='cuda:0', dtype=torch.float64) tensor(49., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(1., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(49., device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(5., device='cuda:0', dtype=torch.float64) tensor(49., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(5., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(49., device='cuda:0', dtype=torch.float64)
# tensor(8., device='cuda:0', dtype=torch.float64) tensor(48., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(4., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(2., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(8., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(48., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(2., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(5., device='cuda:0', dtype=torch.float64) tensor(49., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(49., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(45., device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(49., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(44., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(44., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(42., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(2., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(44., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(49., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(1., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(1., device='cuda:0', dtype=torch.float64) tensor(45., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(3., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(1., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(2., device='cuda:0', dtype=torch.float64) tensor(45., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(1., device='cuda:0', dtype=torch.float64) tensor(48., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(48., device='cuda:0', dtype=torch.float64)
# tensor(1., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(2., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# Epoch [2/3], Loss: 333.6695
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(49., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(1., device='cuda:0', dtype=torch.float64) tensor(49., device='cuda:0', dtype=torch.float64)
# tensor(1., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(1., device='cuda:0', dtype=torch.float64) tensor(49., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(48., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(1., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(49., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(3., device='cuda:0', dtype=torch.float64) tensor(48., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(1., device='cuda:0', dtype=torch.float64) tensor(49., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(45., device='cuda:0', dtype=torch.float64)
# tensor(2., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(4., device='cuda:0', dtype=torch.float64) tensor(45., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(4., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(45., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(48., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(1., device='cuda:0', dtype=torch.float64) tensor(48., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(6., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(1., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(45., device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(6., device='cuda:0', dtype=torch.float64) tensor(48., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(4., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(3., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(48., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(4., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(1., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(1., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(48., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(2., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(1., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(3., device='cuda:0', dtype=torch.float64) tensor(44., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(2., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(1., device='cuda:0', dtype=torch.float64) tensor(49., device='cuda:0', dtype=torch.float64)
# tensor(4., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(49., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(5., device='cuda:0', dtype=torch.float64) tensor(48., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(48., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(3., device='cuda:0', dtype=torch.float64) tensor(48., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(4., device='cuda:0', dtype=torch.float64) tensor(48., device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(47., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(49., device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(48., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(6., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(0., device='cuda:0', dtype=torch.float64) tensor(46., device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(nan, device='cuda:0', dtype=torch.float64) tensor(nan, device='cuda:0', dtype=torch.float64)
# tensor(1., device='cuda:0', dtype=torch.float64) tensor(49., device='cuda:0', dtype=torch.float64)
# Epoch [3/3], Loss: 258.1727

# %%
# 9. 테스트 예측
model.eval()
predictions = []
with torch.no_grad():
    for images in test_loader:
        images = images.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        predictions.extend(predicted.cpu().numpy())

# %%
# 10. 예측 결과 변환 및 제출 파일 생성
reverse_mapping = {v: k for k, v in label_mapping.items()}
predicted_artists = [reverse_mapping[i] for i in predictions]

submission = pd.read_csv('extracted/sample_submission.csv')
submission['artist'] = predicted_artists
submission.to_csv('submission.csv', index=False)

# %%
# 1. 데이터 로딩
train_df = pd.read_csv('extracted/train.csv')
test_df = pd.read_csv('extracted/test.csv')
artists_info = pd.read_csv('extracted/artists_info.csv')  # 포함

# %%
# 2. 화가 이름 → 숫자 라벨
unique_artists = artists_info['name'].tolist()  # artists_info 기준
label_mapping = {name: i for i, name in enumerate(unique_artists)}

train_df['label'] = train_df['artist'].map(label_mapping)
test_df['label'] = -1  # 테스트 데이터는 예측 대상

# %%
# 3. 이미지 경로 설정
train_df['img_path'] = train_df['img_path']
test_df['img_path'] = test_df['img_path']

# %%
# 4. 이미지 전처리 및 증강 (업그레이드)
train_transform = transforms.Compose([
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
    transforms.ToTensor()
])

test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

# %%
# 5. Dataset 클래스 정의
class ArtDataset(Dataset):
    def __init__(self, dataframe, root_dir, transform=None, is_test=False):
        self.dataframe = dataframe
        self.root_dir = root_dir
        self.transform = transform
        self.is_test = is_test

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        img_name = self.dataframe.iloc[idx]['img_path']
        img_path = os.path.join(self.root_dir, img_name)
        image = Image.open(img_path).convert("RGB")
        if self.transform:
            image = self.transform(image)

        if self.is_test:
            return image
        else:
            label = self.dataframe.iloc[idx]['label']
            return image, label

# %%
# 6. 데이터로더
train_dataset = ArtDataset(train_df, 'extracted', transform=train_transform)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

test_dataset = ArtDataset(test_df, 'extracted', transform=test_transform, is_test=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
# 7. 모델 정의 (ResNet18 그대로 사용)
from torchvision.models import resnet18, ResNet18_Weights

# 모델 정의 (ResNet18 사용)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# weights를 ResNet18_Weights.DEFAULT로 변경
model = resnet18(weights=ResNet18_Weights.DEFAULT)
model.fc = nn.Linear(model.fc.in_features, len(label_mapping))
model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)

# %%
# 모델 정의 (이미 이전에 정의된 코드)
from torchvision.models import resnet18, ResNet18_Weights

weights = ResNet18_Weights.DEFAULT  # 최신 가중치
model = resnet18(weights=weights)
model.fc = nn.Linear(model.fc.in_features, len(label_mapping))
model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)  # 학습률 ↓

# 학습 코드
from sklearn.metrics import accuracy_score

num_epochs = 10  # 에폭 증가

for epoch in range(num_epochs):
    model.train()
    total_loss = 0
    all_preds = []
    all_labels = []

    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device).long()
        labels = torch.clamp(labels, min=0)

        outputs = model(images)
        loss = criterion(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

        # 정확도 측정을 위한 예측 수집
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

    acc = accuracy_score(all_labels, all_preds)
    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {total_loss:.4f}, Acc: {acc:.4f}")
# Out:
# Epoch [1/10], Loss: 463.9901, Acc: 0.3739
# Epoch [2/10], Loss: 299.9259, Acc: 0.5718
# Epoch [3/10], Loss: 238.3486, Acc: 0.6515
# Epoch [4/10], Loss: 201.9562, Acc: 0.7024
# Epoch [5/10], Loss: 177.9903, Acc: 0.7313
# Epoch [6/10], Loss: 158.5414, Acc: 0.7645
# Epoch [7/10], Loss: 148.3062, Acc: 0.7731
# Epoch [8/10], Loss: 131.2661, Acc: 0.8016
# Epoch [9/10], Loss: 118.0734, Acc: 0.8208
# Epoch [10/10], Loss: 108.1817, Acc: 0.8337

# %%
# 9. 테스트 예측
model.eval()
predictions = []
with torch.no_grad():
    for images in test_loader:
        images = images.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        predictions.extend(predicted.cpu().numpy())

# %%
# 10. 예측 결과 변환 및 제출 파일 생성
reverse_mapping = {v: k for k, v in label_mapping.items()}
predicted_artists = [reverse_mapping[i] for i in predictions]

submission = pd.read_csv('extracted/sample_submission.csv')
submission['artist'] = predicted_artists
submission.to_csv('submission2.csv', index=False)

# %%
import pandas as pd
import os
from PIL import Image
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import torch.nn as nn
import torch.optim as optim
from torchvision.models import resnet18, ResNet18_Weights
from sklearn.metrics import accuracy_score
from torch.optim.lr_scheduler import CosineAnnealingLR
import numpy as np

# %%
# 1. 데이터 로딩
try:
    train_df = pd.read_csv('extracted/train.csv')
    test_df = pd.read_csv('extracted/test.csv')
    artists_info = pd.read_csv('extracted/artists_info.csv')  # 포함
except FileNotFoundError as e:
    print(f"Error loading file: {e}. Please ensure the files are in the 'extracted' directory.")
    exit()

# %%
# 2. 화가 이름 → 숫자 라벨
unique_artists = artists_info['name'].tolist()  # artists_info 기준
label_mapping = {name: i for i, name in enumerate(unique_artists)}

train_df['label'] = train_df['artist'].map(label_mapping)
test_df['label'] = -1  # 테스트 데이터는 예측 대상

# %%
# 3. 이미지 경로 설정
train_df['img_path'] = train_df['img_path']
test_df['img_path'] = test_df['img_path']

# %%
# 4. 이미지 전처리 및 증강 (업그레이드)
train_transform = transforms.Compose([
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),  # 각도 증가
    transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3, hue=0.1),  # 범위 증가
    transforms.RandomAffine(degrees=0, translate=(0.1, 0.1), scale=(0.9, 1.1)),
    # Affine 변환 추가
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    # 정규화 추가
])

test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    # 정규화 추가
])

# %%
class ArtDataset(Dataset):
    def __init__(self, dataframe, root_dir, transform=None, is_test=False):
        self.dataframe = dataframe
        self.root_dir = root_dir
        self.transform = transform
        self.is_test = is_test
        self.valid_indices = self._get_valid_indices()

    def _get_valid_indices(self):
        valid_indices = []
        for idx in range(len(self.dataframe)):
            label = self.dataframe.iloc[idx]['label']
            if not pd.isna(label):
                try:
                    int(label)
                    valid_indices.append(idx)
                except ValueError:
                    print(f"Warning: Invalid label '{label}' at index {idx}")
            else:
                print(f"Warning: NaN value found for label at index {idx}")
        return valid_indices

    def __len__(self):
        return len(self.valid_indices)

    def __getitem__(self, idx):
        original_index = self.valid_indices[idx]
        img_name = self.dataframe.iloc[original_index]['img_path']
        img_path = os.path.join(self.root_dir, img_name)
        try:
            image = Image.open(img_path).convert("RGB")
        except FileNotFoundError:
            print(f"Error: Image not found at {img_path}")
            return None

        if self.transform:
            image = self.transform(image)

        if self.is_test:
            return image
        else:
            label = int(self.dataframe.iloc[original_index]['label'])
            return image, torch.tensor(label, dtype=torch.long)

# %%
# 6. 데이터로더
train_dataset = ArtDataset(train_df, 'extracted', transform=train_transform)
train_loader = DataLoader(
    train_dataset, batch_size=32, shuffle=True, num_workers=2, drop_last=True
)  # num_workers 추가 and drop_last

test_dataset = ArtDataset(
    test_df, 'extracted', transform=test_transform, is_test=True
)
test_loader = DataLoader(
    test_dataset, batch_size=32, shuffle=False, num_workers=2
)  # num_workers 추가
# Out:
# Warning: NaN value found for label at index 42
# Warning: NaN value found for label at index 54
# Warning: NaN value found for label at index 58
# Warning: NaN value found for label at index 77
# Warning: NaN value found for label at index 94
# Warning: NaN value found for label at index 109
# Warning: NaN value found for label at index 142
# Warning: NaN value found for label at index 146
# Warning: NaN value found for label at index 205
# Warning: NaN value found for label at index 213
# Warning: NaN value found for label at index 215
# Warning: NaN value found for label at index 241
# Warning: NaN value found for label at index 284
# Warning: NaN value found for label at index 378
# Warning: NaN value found for label at index 419
# Warning: NaN value found for label at index 427
# Warning: NaN value found for label at index 442
# Warning: NaN value found for label at index 455
# Warning: NaN value found for label at index 475
# Warning: NaN value found for label at index 480
# Warning: NaN value found for label at index 547
# Warning: NaN value found for label at index 578
# Warning: NaN value found for label at index 581
# Warning: NaN value found for label at index 606
# Warning: NaN value found for label at index 621
# Warning: NaN value found for label at index 668
# Warning: NaN value found for label at index 726
# Warning: NaN value found for label at index 746
# Warning: NaN value found for label at index 747
# Warning: NaN value found for label at index 796
# Warning: NaN value found for label at index 822
# Warning: NaN value found for label at index 836
# Warning: NaN value found for label at index 887
# Warning: NaN value found for label at index 933
# Warning: NaN value found for label at index 965
# Warning: NaN value found for label at index 977
# Warning: NaN value found for label at index 978
# Warning: NaN value found for label at index 979
# Warning: NaN value found for label at index 1000
# Warning: NaN value found for label at index 1001
# Warning: NaN value found for label at index 1081
# Warning: NaN value found for label at index 1088
# Warning: NaN value found for label at index 1133
# Warning: NaN value found for label at index 1142
# Warning: NaN value found for label at index 1149
# Warning: NaN value found for label at index 1211
# Warning: NaN value found for label at index 1218
# Warning: NaN value found for label at index 1221
# Warning: NaN value found for label at index 1234
# Warning: NaN value found for label at index 1235
# Warning: NaN value found for label at index 1263
# Warning: NaN value found for label at index 1289
# Warning: NaN value found for label at index 1322
# Warning: NaN value found for label at index 1333
# Warning: NaN value found for label at index 1365
# Warning: NaN value found for label at index 1388
# Warning: NaN value found for label at index 1402
# Warning: NaN value found for label at index 1412
# Warning: NaN value found for label at index 1466
# Warning: NaN value found for label at index 1488
# Warning: NaN value found for label at index 1498
# Warning: NaN value found for label at index 1536
# Warning: NaN value found for label at index 1547
# Warning: NaN value found for label at index 1553
# Warning: NaN value found for label at index 1556
# Warning: NaN value found for label at index 1610
# Warning: NaN value found for label at index 1618
# Warning: NaN value found for label at index 1622
# Warning: NaN value found for label at index 1670
# Warning: NaN value found for label at index 1686
# Warning: NaN value found for label at index 1702
# Warning: NaN value found for label at index 1719
# Warning: NaN value found for label at index 1725
# Warning: NaN value found for label at index 1729
# Warning: NaN value found for label at index 1751
# Warning: NaN value found for label at index 1754
# Warning: NaN value found for label at index 1757
# Warning: NaN value found for label at index 1768
# Warning: NaN value found for label at index 1780
# Warning: NaN value found for label at index 1851
# Warning: NaN value found for label at index 1926
# Warning: NaN value found for label at index 1949
# Warning: NaN value found for label at index 1967
# Warning: NaN value found for label at index 2055
# Warning: NaN value found for label at index 2092
# Warning: NaN value found for label at index 2095
# Warning: NaN value found for label at index 2130
# Warning: NaN value found for label at index 2144
# Warning: NaN value found for label at index 2146
# Warning: NaN value found for label at index 2152
# Warning: NaN value found for label at index 2172
# Warning: NaN value found for label at index 2189
# Warning: NaN value found for label at index 2227
# Warning: NaN value found for label at index 2253
# Warning: NaN value found for label at index 2254
# Warning: NaN value found for label at index 2281
# Warning: NaN value found for label at index 2322
# Warning: NaN value found for label at index 2403
# Warning: NaN value found for label at index 2415
# Warning: NaN value found for label at index 2426
# Warning: NaN value found for label at index 2473
# Warning: NaN value found for label at index 2521
# Warning: NaN value found for label at index 2565
# Warning: NaN value found for label at index 2597
# Warning: NaN value found for label at index 2637
# Warning: NaN value found for label at index 2648
# Warning: NaN value found for label at index 2677
# Warning: NaN value found for label at index 2691
# Warning: NaN value found for label at index 2735
# Warning: NaN value found for label at index 2791
# Warning: NaN value found for label at index 2801
# Warning: NaN value found for label at index 2916
# Warning: NaN value found for label at index 2936
# Warning: NaN value found for label at index 2963
# Warning: NaN value found for label at index 2980
# Warning: NaN value found for label at index 3078
# Warning: NaN value found for label at index 3094
# Warning: NaN value found for label at index 3112
# Warning: NaN value found for label at index 3135
# Warning: NaN value found for label at index 3139
# Warning: NaN value found for label at index 3219
# Warning: NaN value found for label at index 3249
# Warning: NaN value found for label at index 3255
# Warning: NaN value found for label at index 3345
# Warning: NaN value found for label at index 3423
# Warning: NaN value found for label at index 3453
# Warning: NaN value found for label at index 3466
# Warning: NaN value found for label at index 3474
# Warning: NaN value found for label at index 3482
# Warning: NaN value found for label at index 3570
# Warning: NaN value found for label at index 3594
# Warning: NaN value found for label at index 3606
# Warning: NaN value found for label at index 3645
# Warning: NaN value found for label at index 3660
# Warning: NaN value found for label at index 3667
# Warning: NaN value found for label at index 3672
# Warning: NaN value found for label at index 3725
# Warning: NaN value found for label at index 3741
# Warning: NaN value found for label at index 3746
# Warning: NaN value found for label at index 3775
# Warning: NaN value found for label at index 3780
# Warning: NaN value found for label at index 3798
# Warning: NaN value found for label at index 3804
# Warning: NaN value found for label at index 3809
# Warning: NaN value found for label at index 3818
# Warning: NaN value found for label at index 3836
# Warning: NaN value found for label at index 3846
# Warning: NaN value found for label at index 3853
# Warning: NaN value found for label at index 3954
# Warning: NaN value found for label at index 3963
# Warning: NaN value found for label at index 3970
# Warning: NaN value found for label at index 3981
# Warning: NaN value found for label at index 4010
# Warning: NaN value found for label at index 4058
# Warning: NaN value found for label at index 4070
# Warning: NaN value found for label at index 4107
# Warning: NaN value found for label at index 4122
# Warning: NaN value found for label at index 4144
# Warning: NaN value found for label at index 4164
# Warning: NaN value found for label at index 4182
# Warning: NaN value found for label at index 4185
# Warning: NaN value found for label at index 4204
# Warning: NaN value found for label at index 4216
# Warning: NaN value found for label at index 4221
# Warning: NaN value found for label at index 4257
# Warning: NaN value found for label at index 4276
# Warning: NaN value found for label at index 4294
# Warning: NaN value found for label at index 4304
# Warning: NaN value found for label at index 4311
# Warning: NaN value found for label at index 4331
# Warning: NaN value found for label at index 4337
# Warning: NaN value found for label at index 4374
# Warning: NaN value found for label at index 4379
# Warning: NaN value found for label at index 4393
# Warning: NaN value found for label at index 4454
# Warning: NaN value found for label at index 4471
# Warning: NaN value found for label at index 4484
# Warning: NaN value found for label at index 4511
# Warning: NaN value found for label at index 4580
# Warning: NaN value found for label at index 4615
# Warning: NaN value found for label at index 4653
# Warning: NaN value found for label at index 4735
# Warning: NaN value found for label at index 4777
# Warning: NaN value found for label at index 4786
# Warning: NaN value found for label at index 4807
# Warning: NaN value found for label at index 4829
# Warning: NaN value found for label at index 4832
# Warning: NaN value found for label at index 4836
# Warning: NaN value found for label at index 4843
# Warning: NaN value found for label at index 4887
# Warning: NaN value found for label at index 4888
# Warning: NaN value found for label at index 4896
# Warning: NaN value found for label at index 4932
# Warning: NaN value found for label at index 4934
# Warning: NaN value found for label at index 4986
# Warning: NaN value found for label at index 5017
# Warning: NaN value found for label at index 5059
# Warning: NaN value found for label at index 5069
# Warning: NaN value found for label at index 5124
# Warning: NaN value found for label at index 5137
# Warning: NaN value found for label at index 5142
# Warning: NaN value found for label at index 5218
# Warning: NaN value found for label at index 5325
# Warning: NaN value found for label at index 5394
# Warning: NaN value found for label at index 5517
# Warning: NaN value found for label at index 5526
# Warning: NaN value found for label at index 5547
# Warning: NaN value found for label at index 5616
# Warning: NaN value found for label at index 5633
# Warning: NaN value found for label at index 5641
# Warning: NaN value found for label at index 5648
# Warning: NaN value found for label at index 5668
# Warning: NaN value found for label at index 5693
# Warning: NaN value found for label at index 5712
# Warning: NaN value found for label at index 5738
# Warning: NaN value found for label at index 5745
# Warning: NaN value found for label at index 5811
# Warning: NaN value found for label at index 5840
# Warning: NaN value found for label at index 5857
# Warning: NaN value found for label at index 5886

# %%
# 7. 모델 정의 (ResNet18 그대로 사용)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

weights = ResNet18_Weights.DEFAULT  # 최신 가중치
model = resnet18(weights=weights)
model.fc = nn.Linear(model.fc.in_features, len(label_mapping))
model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(
    model.parameters(), lr=1e-4, weight_decay=0.01
)  # AdamW 사용 및 weight_decay 추가
scheduler = CosineAnnealingLR(optimizer, T_max=50)  # CosineAnnealingLR 스케줄러 추가
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 140MB/s]

# %%
# 학습 코드
num_epochs = 50  # 에폭 증가

for epoch in range(num_epochs):
    model.train()
    total_loss = 0
    all_preds = []
    all_labels = []

    for i, batch in enumerate(train_loader):
        if batch is None:
            print(f"Warning: Skipping batch {i} due to None values.")
            continue  # Skip this batch

        images, labels = batch
        if images is None or labels is None:
            print(f"Warning: Skipping batch {i} due to None images or labels.")
            continue

        images, labels = images.to(device), labels.to(device)

        outputs = model(images)
        loss = criterion(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

        if i % 10 == 0:  # Logging frequency
            print(
                f"Epoch [{epoch + 1}/{num_epochs}], Step [{i + 1}/{len(train_loader)}], Loss:"
                f" {loss.item():.4f}"
            )

    scheduler.step()  # 에폭마다 스케줄러 업데이트
    acc = accuracy_score(all_labels, all_preds)
    print(
        f"Epoch [{epoch + 1}/{num_epochs}], Loss: {total_loss / len(train_loader):.4f},"
        f" Acc: {acc:.4f}, LR: {optimizer.param_groups[0]['lr']:.6f}"
    )
# Out:
# Epoch [1/50], Step [1/177], Loss: 4.2157
# Epoch [1/50], Step [11/177], Loss: 3.5160
# Epoch [1/50], Step [21/177], Loss: 3.4993
# Epoch [1/50], Step [31/177], Loss: 2.7081
# Epoch [1/50], Step [41/177], Loss: 2.9371
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-dd9bc3406dd9> in <cell line: 0>()
#      24
#      25         optimizer.zero_grad()
# ---> 26         loss.backward()
#      27         optimizer.step()
#      28         total_loss += loss.item()
#
# /usr/local/lib/python3.11/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     624                 inputs=inputs,
#     625             )
# --> 626         torch.autograd.backward(
#     627             self, gradient, retain_graph, create_graph, inputs=inputs
#     628         )
#
# /usr/local/lib/python3.11/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     345     # some Python versions print out the first line of a multi-line function
#     346     # calls in the traceback and some print out the last line
# --> 347     _engine_run_backward(
#     348         tensors,
#     349         grad_tensors_,
#
# /usr/local/lib/python3.11/dist-packages/torch/autograd/graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     821         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     822     try:
# --> 823         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     824             t_outputs, *args, **kwargs
#     825         )  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %%
# 9. 테스트 예측
model.eval()
predictions = []
with torch.no_grad():
    for images in test_loader:
        images = images.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        predictions.extend(predicted.cpu().numpy())

print("Test predictions:", predictions)

# %%
submission_df = pd.DataFrame({'id': test_df['id'], 'artist': [unique_artists[p] for p in predictions]})
submission_df.to_csv('submission.csv5', index=False)
